# %%
# topography affects fire speed and therefore fire danger ref = 'https://www.environment.sa.gov.au/topics/fire-management/fire-science/fire-behaviour'
#
#
#
3
#
# Out:
# 3

# %%
from __future__ import (absolute_import, division, print_function)
import os
import json

import matplotlib as mpl
import matplotlib.pyplot as plt

from shapely.geometry import Point, Polygon, MultiPolygon
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
from geoalchemy2 import Geometry, WKTElement
from sqlalchemy import *
from sqlalchemy import create_engine
import psycopg2
import psycopg2.extras

data_path = "./Assignment_files"
print('done')

# %%
# %matplotlib inline
print('done')
# Out:
# done

# %%
print('y')
# Out:
# y

# %%
rfsnswbfpl = gpd.read_file( os.path.join(data_path,"RFSNSW_BFPL-Copy1.shp") )
geom_srid_num  = gpd.tools.crs.epsg_from_crs(rfsnswbfpl.crs)
print(geom_srid_num)
# Out:
# 4283
# /opt/jupyterhub/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: epsg_from_crs is deprecated. You can get the epsg code from GeoDataFrame (gdf) using gdf.crs.to_epsg()

# %%
rfsnswbfpl.head()
# Out:
#    CATEGORY  SHAPE_LENG    SHAPE_AREA                     geometry
# 0         1    0.000017  5.392400e-12  POINT (149.11319 -33.05824)
# 1         1    0.000178  1.140005e-09  POINT (152.27536 -29.68316)
# 2         1    0.000890  4.950178e-08  POINT (152.14244 -29.68266)
# 3         1    0.000442  8.094091e-09  POINT (152.27579 -29.68259)
# 4         1    0.000890  4.950155e-08  POINT (151.99619 -29.68131)

# %%
sa2_2016_aust = gpd.read_file( os.path.join(data_path,"SA2_2016_AUST.shp") )
qq  = gpd.tools.crs.epsg_from_crs(sa2_2016_aust.crs)
print(qq)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-eef9299bd0b0> in <module>
# ----> 1 sa2_2016_aust = gpd.read_file( os.path.join(data_path,"SA2_2016_AUST.shp") )
#       2 qq  = gpd.tools.crs.epsg_from_crs(sa2_2016_aust.crs)
#       3 print(qq)
#
# /opt/jupyterhub/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#     125
#     126             columns = list(features.meta["schema"]["properties"]) + ["geometry"]
# --> 127             gdf = GeoDataFrame.from_features(f_filt, crs=crs, columns=columns)
#     128
#     129     return gdf
#
# /opt/jupyterhub/lib/python3.7/site-packages/geopandas/geodataframe.py in from_features(cls, features, crs, columns)
#     292
#     293         rows = []
# --> 294         for f in features_lst:
#     295             if hasattr(f, "__geo_interface__"):
# ...

# %%
spotheight = gpd.read_file( os.path.join(data_path,'SpotHeight_EPSG4326.json'))
aq  = gpd.tools.crs.epsg_from_crs(spotheight.crs)
print(aq)
# Out:
# 4326
# /opt/jupyterhub/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: epsg_from_crs is deprecated. You can get the epsg code from GeoDataFrame (gdf) using gdf.crs.to_epsg()

# %%
spotheight.head()
# Out:
#       topoid objectmoddate featuremoddate  classsubtype  \
# 0  503947832          None           None             1
# 1  503947833          None           None             1
# 2  503947993          None           None             1
# 3  503947994          None           None             1
# 4  503947995          None           None             1
#
#   featurereliabilitydate attributereliabilitydate  capturesourcecode  \
# 0         20000214000000           20000214000000                  4
# 1         20000214000000           20000214000000                  4
# 2         20000202000000           20000202000000                  4
# 3         20000202000000           20000202000000                  4
# 4         20000202000000           20000202000000                  4
#
#    capturemethodcode  planimetricaccuracy verticalaccuracy  ...  \
# 0                  2                   10             None  ...
# 1                  2                   10             None  ...
# ...

# %%
print(test.sort_values(by = ['CATEGORY']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-758225c8be10> in <module>
# ----> 1 print(test.sort_values(by = ['CATEGORY']))
#
# NameError: name 'test' is not defined

# %%
print(type(sa2_2016_aust))

# %%
Sydneyspacial = sa2_2016_aust[sa2_2016_aust.GCC_NAME16 == 'Greater Sydney']
Sydneyspacial

# %%
print(Ausspacial.head().geom_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-288feb180b2f> in <module>
# ----> 1 print(Ausspacial.head().geom_type)
#
# NameError: name 'Ausspacial' is not defined

# %%
neighbourhoods = pd.read_csv('Neighbourhoods.csv')

# %%
businessstats = pd.read_csv('BusinessStats.csv')

# %%
statisticalareas = pd.read_csv('StatisticalAreas.csv')

# %%
relativeheight = pd.read_csv('RelativeHeight.csv')

# %%
relativeheight
# Out:
#          topoid  objectmoddate  featuremoddate  classsubtype  \
# 0     503947832            NaN             NaN             1
# 1     503947833            NaN             NaN             1
# 2     503947993            NaN             NaN             1
# 3     503947994            NaN             NaN             1
# 4     503947995            NaN             NaN             1
# ...         ...            ...             ...           ...
# 1104  512889278            NaN             NaN             1
# 1105  513287628            NaN             NaN             1
# 1106  515466727            NaN             NaN             1
# 1107  515466739            NaN             NaN             1
# 1108  515466763            NaN             NaN             1
#
#       featurereliabilitydate  attributereliabilitydate  capturesourcecode  \
# 0             20000214000000            20000214000000                  4
# 1             20000214000000            20000214000000                  4
# ...

# %%
getinfo(neighbourhoods)
getinfo(businessstats)
getinfo(statisticalareas)
getinfo(relativeheight)
# Out:
# 322 data points and colums of: ['area_id', 'area_name', 'land_area', 'population', 'number_of_dwellings', 'number_of_businesses', 'median_annual_household_income', 'avg_monthly_rent']
# 2301 data points and colums of: ['area_id', 'area_name', 'number_of_businesses', 'accommodation_and_food_services', 'retail_trade', 'agriculture_forestry_and_fishing', 'health_care_and_social_assistance', 'public_administration_and_safety', 'transport_postal_and_warehousing']
# 434 data points and colums of: ['area_id', 'area_name', 'parent_area_id']
# ...

# %%
def getinfo(data):
    icount = len(data)
    deep_info = (str(icount)+' data points and colums of: ' + str(data.columns.values.tolist()))
    print(deep_info)

#nieghboursinfo = (' 322 data points and colums of: ' + str(neighdata.columns.values.tolist()))
#print(nieghboursinfo)
getinfo(mainareasdata)
# neigh data has 322 data points
#print(bussdata.head())
#print(statareadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7c413355d877> in <module>
#       6 #nieghboursinfo = (' 322 data points and colums of: ' + str(neighdata.columns.values.tolist()))
#       7 #print(nieghboursinfo)
# ----> 8 getinfo(mainareasdata)
#       9 # neigh data has 322 data points
#      10 #print(bussdata.head())
#
# NameError: name 'mainareasdata' is not defined

# %%
import psycopg2
import psycopg2.extras
def pgconnect():
    YOUR_UNIKEY = '<your_unikey>'
    YOUR_PW     = '<your_SID>'
    DB_LOGIN    = 'y21s1d2x01_'+YOUR_UNIKEY

    try:
        db = create_engine('postgres+psycopg2://'+DB_LOGIN+':'+YOUR_PW+'@soitpw11d59.shared.sydney.edu.au/'+DB_LOGIN, echo=False)
        conn = db.connect()
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return db,conn

def pgconnect_using_credfile(credential_filepath):
    try:
        with open(credential_filepath) as f:
            db_conn_dict = json.load(f)
        connstring = 'postgres+psycopg2://'+db_conn_dict['user']+':'+db_conn_dict['password']+'@'+db_conn_dict['host']+'/'+db_conn_dict['database']
        db = create_engine(connstring, echo=False)
        conn = db.connect()
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
        return None
    return db,conn

# %%
# please update the details in data2x01_db.json
credfilepath = os.path.join(data_path, "data2x01_db-Copy1.json")
# credfilepath = os.path.join(data_path, "data2001_dbadmin.json")
# credfilepath = os.path.join(data_path, "data2001_db95.json")
db, conn = pgconnect_using_credfile(credfilepath)
# Out:
# connected

# %%
def pgexecute( conn, sqlcmd, args=None, msg='', silent=False ):
    """ utility function to execute some SQL query statement
       can take optional arguments to fill in (dictionary)
       will print out on screen the result set of the query
       error and transaction handling built-in """
    retval = False
    result_set = None

    try:
        if args is None:
            result_set = conn.execute(sqlcmd).fetchall()
        else:
            result_set = conn.execute(sqlcmd, args).fetchall()

        if silent == False: 
            print("success: " + msg)
            for record in result_set:
                print(record)
        retval = True
    except Exception as e:
        if silent == False:
            print("db read error: ")
            print(e)
    return retval

def pgquery( conn, sqlcmd, args=None, silent=False ):
    """ utility function to execute some SQL query statement
    can take optional arguments to fill in (dictionary)
    will print out on screen the result set of the query
    error and transaction handling built-in """
    retdf = pd.DataFrame()
    retval = False
    try:
        if args is None:
            retdf = pd.read_sql_query(sqlcmd,conn)
        else:
            retdf = pd.read_sql_query(sqlcmd,conn,params=args)
        if silent == False:
            print(retdf.shape)
            print(retdf.to_string())
        retval = True
    except Exception as e:
        if silent == False:
            print("db read error: ")
            print(e)
    return retval,retdf

# %%
postgis_check = '''
SELECT PostGIS_Version();
'''

retval,retdf = pgquery(conn,postgis_check)
retdf
# Out:
# (1, 1)
#                          postgis_version
# 0  3.0 USE_GEOS=1 USE_PROJ=1 USE_STATS=1
#                          postgis_version
# 0  3.0 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %%
gsydney_schema = '''CREATE TABLE gsydney (
                     pop_est NUMERIC, 
                     continent VARCHAR(80), 
                     name VARCHAR(80), 
                     iso_a3 VARCHAR(80), 
                     gdp_md_est NUMERIC,
                     geom GEOMETRY(MULTIPOLYGON,4326))''' 

conn.execute("DROP TABLE IF EXISTS world")
conn.execute(world_schema)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-d9645b4a8995> in <module>
#       8
#       9 conn.execute("DROP TABLE IF EXISTS world")
# ---> 10 conn.execute(world_schema)
#
# NameError: name 'world_schema' is not defined

# %%
# all data files
# rfsnswbfpl
# sa22016aust
# neighbourhoods
# businessstats
# statisticalareas
# spotheight
# relativeheight

# %%
sa2_2016_austdrop = sa2_2016_aust.dropna()

# %%
delcolumns = ["SA3_CODE16","SA3_NAME16","SA4_CODE16","SA4_NAME16","STE_CODE16","STE_NAME16","AREASQKM16"]
usa2_2016_austdrop = sa2_2016_austdrop.drop(columns=delcolumns)
srid = 4326
def create_wkt_element(geom,srid):
    if (geom.geom_type == 'Polygon'):
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

sa2_2016_austWkCpy = usa2_2016_austdrop.copy()
sa2_2016_austWkCpy["geom"] = sa2_2016_austdrop['geometry'].apply(lambda x: create_wkt_element(x,srid))
sa2_2016_austWkCpy = sa2_2016_austWkCpy.drop(columns="geometry")
sa2_2016_austWkCpy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7d7ee81372fc> in <module>
#       1 delcolumns = ["SA3_CODE16","SA3_NAME16","SA4_CODE16","SA4_NAME16","STE_CODE16","STE_NAME16","AREASQKM16"]
# ----> 2 usa2_2016_austdrop = sa2_2016_austdrop.drop(columns=delcolumns)
#       3 srid = 4326
#       4 def create_wkt_element(geom,srid):
#       5     if (geom.geom_type == 'Polygon'):
#
# NameError: name 'sa2_2016_austdrop' is not defined

# %%
srid = 4326
def create_wkt_elementpoint(geom,srid):
    if (geom.geom_type == 'PointZ'):
        geom = Point([geom])
    return WKTElement(geom.wkt, srid)

# %%
spotheightdrop = spotheight.dropna(subset = ['geometry'])
spotheightWkCpy = spotheightdrop.copy()
spotheightWkCpy['geom'] = spotheightdrop['geometry'].apply(lambda geom: WKTElement(geom.wkt, srid = srid))
spotheightWkCpy = spotheightWkCpy.drop(columns="geometry")
spotheightWkCpy
# Out:
#         topoid objectmoddate featuremoddate  classsubtype  \
# 0    503947832          None           None             1
# 1    503947833          None           None             1
# 2    503947993          None           None             1
# 3    503947994          None           None             1
# 4    503947995          None           None             1
# ..         ...           ...            ...           ...
# 784  512802478          None           None             1
# 785  512802678          None           None             1
# 786  512802680          None           None             1
# 787  512802682          None           None             1
# 788  512802732          None           None             1
#
#     featurereliabilitydate attributereliabilitydate  capturesourcecode  \
# 0           20000214000000           20000214000000                  4
# 1           20000214000000           20000214000000                  4
# ...

# %%
spotheightdrop = spotheight.dropna(subset = ['geometry'])
delcolumns = ["geometry","objectmoddate","featuremoddate", "classsubtype","featurereliabilitydate","attributereliabilitydate","capturesourcecode","capturemethodcode","planimetricaccuracy","verticalaccuracy","enddate","lastupdate","msoid","centroidid","shapeuuid","changetype","processstate","urbanity","createdate","relevance","startdate"]
spotheightWkCpy = spotheightdrop.copy()
spotheightWkCpy['geom'] = spotheightdrop['geometry'].apply(lambda geom: WKTElement(geom.wkt, srid = srid))
spotheightWkCpy = spotheightWkCpy.drop(columns=delcolumns)
spotheightWkCpy
# Out:
#         topoid  relativeheight  \
# 0    503947832              37
# 1    503947833              35
# 2    503947993              92
# 3    503947994              36
# 4    503947995              62
# ..         ...             ...
# 784  512802478              46
# 785  512802678              53
# 786  512802680              91
# 787  512802682              70
# 788  512802732              27
#
#                                                  geom
# 0    POINT Z (151.1617977641413 -33.50363620271642 0)
# 1    POINT Z (151.2326068223198 -33.60402835658748 0)
# 2    POINT Z (151.2842550059311 -33.55185238290422 0)
# 3    POINT Z (151.3074478967861 -33.55471256496122 0)
# 4    POINT Z (151.3133996918876 -33.53661294551793 0)
# ..                                                ...
# 784  POINT Z (150.2311986348982 -34.07420525029912 0)
# 785  POINT Z (150.2433874249324 -34.06347862933537 0)
# 786  POINT Z (150.2359215589454 -34.06338930311512 0)
# ...

# %%
srid = 4326
def create_wkt_elementpoint(geom,srid):
    if (geom.geom_type == 'PointZ'):
        geom = POINT([geom])
    return WKTElement(geom.wkt, srid)

spotheightWkCpy1 = spotheightWkCpy.copy()
spotheightWkCpy1["geom1"] = spotheightWkCpy['geom'].apply(lambda x: create_wkt_elementpoint(x,srid))
spotheightWkCpy1 = spotheightWkCpy1.drop(columns="geom")
spotheightWkCpy1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-72d27a51be5c> in <module>
#       6
#       7 spotheightWkCpy1 = spotheightWkCpy.copy()
# ----> 8 spotheightWkCpy1["geom1"] = spotheightWkCpy['geom'].apply(lambda x: create_wkt_elementpoint(x,srid))
#       9 spotheightWkCpy1 = spotheightWkCpy1.drop(columns="geom")
#      10 spotheightWkCpy1
#
# /opt/jupyterhub/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-86-72d27a51be5c> in <lambda>(x)
#       6
# ...

# %%
rfsnswbfpldrop = rfsnswbfpl.dropna(subset = ["geometry"])
rfsnswbfplWkCpy = rfsnswbfpldrop.copy()
rfsnswbfplWkCpy['geom'] = rfsnswbfpldrop['geometry'].apply(lambda geom: WKTElement(geom.wkt, srid = srid))
rfsnswbfplWkCpy = rfsnswbfplWkCpy.drop(columns="geometry")
rfsnswbfplWkCpy
# Out:
#         CATEGORY  SHAPE_LENG    SHAPE_AREA  \
# 0              1    0.000017  5.392400e-12
# 1              1    0.000178  1.140005e-09
# 2              1    0.000890  4.950178e-08
# 3              1    0.000442  8.094091e-09
# 4              1    0.000890  4.950155e-08
# ...          ...         ...           ...
# 516628         2    0.000942  3.484545e-08
# 516629         2    0.000457  8.385178e-09
# 516630         2    0.001833  1.341083e-07
# 516631         2    0.012603  3.187411e-06
# 516632         2    0.000555  8.779539e-09
#
#                                                 geom
# 0       POINT (149.1131894786667 -33.05824346699998)
# 1       POINT (152.2753625074807 -29.68315654934266)
# 2       POINT (152.1424400005001 -29.68265650149996)
# 3       POINT (152.2757861369404 -29.68259377308781)
# 4           POINT (151.996189999 -29.68130649949998)
# ...                                              ...
# 516628   POINT (153.4999428785902 -28.4766288807896)
# ...

# %%
conn.execute("DROP TABLE IF EXISTS rfsnswbfpl")

# 2nd: ensure that the schema is in place
rfsnswbfpl_schema = '''CREATE TABLE rfsnswbfpl (
                     category INT, 
                     shape_leng NUMERIC, 
                     shape_area NUMERIC,
                     geom GEOMETRY(POINT,4326))''' 
conn.execute("DROP TABLE IF EXISTS rfsnswbfpl")
conn.execute(rfsnswbfpl_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'spotheight', 'sa2_2016_aust', 'rfsnswbfpl', 'businessstats', 'neighbourhoods', 'organisations', 'relative_height', 'spatial_ref_sys', 'statisticalareas']

# %%
rfsnswbfplWkCpy.columns = rfsnswbfplWkCpy.columns.str.lower()

# %%
rfsnswbfplWkCpy
# Out:
#         category  shape_leng    shape_area  \
# 0              1    0.000017  5.392400e-12
# 1              1    0.000178  1.140005e-09
# 2              1    0.000890  4.950178e-08
# 3              1    0.000442  8.094091e-09
# 4              1    0.000890  4.950155e-08
# ...          ...         ...           ...
# 516628         2    0.000942  3.484545e-08
# 516629         2    0.000457  8.385178e-09
# 516630         2    0.001833  1.341083e-07
# 516631         2    0.012603  3.187411e-06
# 516632         2    0.000555  8.779539e-09
#
#                                                 geom
# 0       POINT (149.1131894786667 -33.05824346699998)
# 1       POINT (152.2753625074807 -29.68315654934266)
# 2       POINT (152.1424400005001 -29.68265650149996)
# 3       POINT (152.2757861369404 -29.68259377308781)
# 4           POINT (151.996189999 -29.68130649949998)
# ...                                              ...
# 516628   POINT (153.4999428785902 -28.4766288807896)
# ...

# %%
table_name = "rfsnswbfpl"
rfsnswbfplWkCpy.to_sql(table_name, conn, if_exists='append', index=False, 
                         dtype={"geom": Geometry('Point', srid)})
query = "SELECT COUNT(*) FROM rfsnswbfpl"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# (1, 1)
#     count
# 0  516633
#     count
# 0  516633

# %%
# Out:
# (1, 1)
#     count
# 0  516633
#     count
# 0  516633

# %%
_?_?_?_?_?_?_?_

# %%
_____________________

# %%
## now will create the sql table
spotheightWkCpy.head()
spotheightWkCpy['geom'] = points
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-549bf32952b6> in <module>
#       1 ## now will create the sql table
#       2 spotheightWkCpy.head()
# ----> 3 spotheightWkCpy['geom'] = points
#
# NameError: name 'points' is not defined

# %%
# spotheightWkCpy
# if you want to reset the table
conn.execute("DROP TABLE IF EXISTS spotheight")

# 2nd: ensure that the schema is in place
spot_height_schema = '''CREATE TABLE spotheight (
                     topoid INT, 
                     relativeheight NUMERIC, 
                     geom GEOMETRY(POINTZ,4326),
                     PRIMARY KEY(topoid))''' 
conn.execute(spot_height_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'sa2_2016_aust', 'rfsnswbfpl', 'spotheight', 'businessstats', 'neighbourhoods', 'organisations', 'relative_height', 'spatial_ref_sys', 'statisticalareas']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dee2033583c9> in <module>
# ----> 1 print(db.table_names())
#
# NameError: name 'db' is not defined

# %%
table_name = "spotheight"
spotheightWkCpy.to_sql(table_name, conn, if_exists='append', index=False, 
                         dtype={'geom': Geometry('PointZ', srid)})

# %%
query = "SELECT COUNT(*) FROM spotheight"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# (1, 1)
#    count
# 0    789
#    count
# 0    789

# %%
_____________________________________

# %%
sa2_2016_austWkCpy
# Out:
#      SA2_MAIN16 SA2_5DIG16               SA2_NAME16 GCC_CODE16  \
# 0     101021007      11007                Braidwood      1RNSW
# 1     101021008      11008                  Karabar      1RNSW
# 2     101021009      11009               Queanbeyan      1RNSW
# 3     101021010      11010        Queanbeyan - East      1RNSW
# 4     101021011      11011        Queanbeyan Region      1RNSW
# ...         ...        ...                      ...        ...
# 2301  801111141      81141                  Namadgi      8ACTE
# 2304  901011001      91001         Christmas Island      9OTER
# 2305  901021002      91002  Cocos (Keeling) Islands      9OTER
# 2306  901031003      91003               Jervis Bay      9OTER
# 2307  901041004      91004           Norfolk Island      9OTER
#
#                         GCC_NAME16  \
# 0                      Rest of NSW
# 1                      Rest of NSW
# 2                      Rest of NSW
# 3                      Rest of NSW
# ...

# %%
print(srid)
# Out:
# 4326

# %%
_?__?_?_?_?-?_

# %%
conn.execute("DROP TABLE IF EXISTS sa2_2016_aust")

# 2nd: ensure that the schema is in place
sa2_2016_aust_schema = '''CREATE TABLE sa2_2016_aust (
                     SA2_MAIN16 INT, 
                     SA2_5DIG16 INT, 
                     SA2_NAME16 VARCHAR(255),  
                     GCC_CODE16 VARCHAR(255),
                     GCC_NAME16 VARCHAR(255),
                     geom GEOMETRY(MULTIPOLYGON,4326))''' 
conn.execute(sa2_2016_aust_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'rfsnswbfpl', 'spotheight', 'sa2_2016_aust', 'businessstats', 'neighbourhoods', 'organisations', 'relative_height', 'spatial_ref_sys', 'statisticalareas']

# %%
sa2_2016_austWkCpy.columns = sa2_2016_austWkCpy.columns.str.lower()

# %%
table_name = "sa2_2016_aust"
sa2_2016_austWkCpy.to_sql(table_name, conn, if_exists='append', index=False, 
                         dtype={'geom': Geometry('MultiPolygon', 4326)})

# %%
_?_?_?__??_?_

# %%
# sa2_2016_austWkCpy _?
# rfsnswbfplWkCpy _?
#spotheight DONE 
#nighbourhoods DONE
#bussinessstats DONE
#statisticalareas DONE

# %%
# Out:
# 322 data points and colums of: ['area_id', 'area_name', 'land_area', 'population', 'number_of_dwellings', 'number_of_businesses', 'median_annual_household_income', 'avg_monthly_rent']
# 2301 data points and colums of: ['area_id', 'area_name', 'number_of_businesses', 'accommodation_and_food_services', 'retail_trade', 'agriculture_forestry_and_fishing', 'health_care_and_social_assistance', 'public_administration_and_safety', 'transport_postal_and_warehousing']
# 434 data points and colums of: ['area_id', 'area_name', 'parent_area_id']
# ...

# %%
____________________________

# %%
neighbourhoods.head()
neighbourhoods['population']=neighbourhoods['population'].str.replace(',','')
neighbourhoods['number_of_dwellings']=neighbourhoods['number_of_dwellings'].str.replace(',','')
#neighbourhoods['population']=neighbourhoods['population'].str.replace(',','')

# %%
conn.execute("DROP TABLE IF EXISTS neighbourhoods")

# 2nd: ensure that the schema is in place
sa2_2016_aust_schema = '''CREATE TABLE neighbourhoods (
                     area_id INT, 
                     area_name VARCHAR(255), 
                     land_area NUMERIC,  
                     population NUMERIC,
                     number_of_dwellings NUMERIC,
                     number_of_businesses NUMERIC,
                     median_annual_household_income NUMERIC,
                     avg_monthly_rent NUMERIC,
                     PRIMARY KEY(area_id))''' 
conn.execute(sa2_2016_aust_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'rfsnswbfpl', 'spotheight', 'sa2_2016_aust', 'neighbourhoods', 'businessstats', 'organisations', 'relative_height', 'spatial_ref_sys', 'statisticalareas']

# %%
table_name = "neighbourhoods"
neighbourhoods.to_sql(table_name, conn, if_exists='append', index=False)

# %%
query = "SELECT COUNT(*) FROM neighbourhoods"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# (1, 1)
#    count
# 0    322
#    count
# 0    322

# %%
____________________________________

# %%
____________________________________

# %%
businessstats.head()
# Out:
#      area_id          area_name  number_of_businesses  \
# 0  101021007          Braidwood                   629
# 1  101021008            Karabar                   326
# 2  101021009         Queanbeyan                   724
# 3  101021010  Queanbeyan - East                   580
# 4  101021011  Queanbeyan Region                  1642
#
#    accommodation_and_food_services  retail_trade  \
# 0                               26            27
# 1                                7            10
# 2                               52            47
# 3                               16            23
# 4                               39            63
#
#    agriculture_forestry_and_fishing  health_care_and_social_assistance  \
# 0                               280                                 11
# 1                                 8                                 11
# 2                                11                                 56
# ...

# %%
conn.execute("DROP TABLE IF EXISTS businessstats")

# 2nd: ensure that the schema is in place
businessstats_schema = '''CREATE TABLE businessstats (
                     area_id INT, 
                     area_name VARCHAR(255), 
                     number_of_businesses INT,  
                     accommodation_and_food_services INT,
                     retail_trade INT,
                     agriculture_forestry_and_fishing INT,
                     health_care_and_social_assistance INT,
                     public_administration_and_safety INT,
                     transport_postal_and_warehousing INT,
                     PRIMARY KEY(area_id))''' 
conn.execute(businessstats_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'rfsnswbfpl', 'spotheight', 'sa2_2016_aust', 'neighbourhoods', 'businessstats', 'organisations', 'relative_height', 'spatial_ref_sys', 'statisticalareas']

# %%
table_name = "businessstats"
businessstats.to_sql(table_name, conn, if_exists='append', index=False)

# %%
query = "SELECT COUNT(*) FROM businessstats"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# (1, 1)
#    count
# 0   2301
#    count
# 0   2301

# %%
_____________________________________/\

# %%
getinfo(statisticalareas)
getinfo(relativeheight)
# Out:
# 434 data points and colums of: ['area_id', 'area_name', 'parent_area_id']
# 1109 data points and colums of: ['topoid', 'objectmoddate', 'featuremoddate', 'classsubtype', 'featurereliabilitydate', 'attributereliabilitydate', 'capturesourcecode', 'capturemethodcode', 'planimetricaccuracy', 'verticalaccuracy', 'relativeheight', 'relevance', 'startdate', 'enddate', 'lastupdate', 'msoid', 'centroidid', 'shapeuuid', 'changetype', 'processstate', 'urbanity', 'cadid', 'createdate', 'modifieddate', 'lganame', 'councilname', 'abscode', 'ltocode', 'vgcode', 'wbcode']

# %%
______________________\/

# %%
statisticalareas.tail()
# Out:
#      area_id                          area_name  parent_area_id
# 429      106        Hunter Valley exc Newcastle              11
# 430    11102              Lake Macquarie - West             111
# 431      111       Newcastle and Lake Macquarie              11
# 432    11402                 Southern Highlands             114
# 433      114  Southern Highlands and Shoalhaven              11

# %%
conn.execute("DROP TABLE IF EXISTS statisticalareas")

# 2nd: ensure that the schema is in place
statisticalareas_schema = '''CREATE TABLE statisticalareas (
                     area_id INT, 
                     area_name VARCHAR(255), 
                     parent_area_id INT)''' 
conn.execute(statisticalareas_schema)
print(db.table_names())
# Out:
# ['MeasuremntW4K', 'measurementw4k', 'rfsnswbfpl', 'spotheight', 'sa2_2016_aust', 'neighbourhoods', 'businessstats', 'statisticalareas', 'organisations', 'relative_height', 'spatial_ref_sys']

# %%
table_name = "statisticalareas"
statisticalareas.to_sql(table_name, conn, if_exists='append', index=False)

# %%
query = "SELECT COUNT(*) FROM statisticalareas"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# (1, 1)
#    count
# 0    434
#    count
# 0    434

# %%
____________________________________/\

# %%
___________________________________\/

# %%
getinfo(relativeheight)
# Out:
# 1109 data points and colums of: ['topoid', 'objectmoddate', 'featuremoddate', 'classsubtype', 'featurereliabilitydate', 'attributereliabilitydate', 'capturesourcecode', 'capturemethodcode', 'planimetricaccuracy', 'verticalaccuracy', 'relativeheight', 'relevance', 'startdate', 'enddate', 'lastupdate', 'msoid', 'centroidid', 'shapeuuid', 'changetype', 'processstate', 'urbanity', 'cadid', 'createdate', 'modifieddate', 'lganame', 'councilname', 'abscode', 'ltocode', 'vgcode', 'wbcode']

# %%
ropis = ['objectmoddate', 'featuremoddate', 'classsubtype', 'featurereliabilitydate', 'attributereliabilitydate', 'capturesourcecode', 'capturemethodcode', 'planimetricaccuracy', 'verticalaccuracy','relevance', 'startdate', 'enddate', 'lastupdate', 'msoid', 'centroidid', 'shapeuuid', 'changetype', 'processstate', 'urbanity', 'cadid', 'createdate', 'modifieddate', 'lganame', 'councilname', 'abscode', 'ltocode', 'vgcode', 'wbcode']
relheight = relativeheight.drop(columns = ropis)
conn.execute("DROP TABLE IF EXISTS relative_height")

# 2nd: ensure that the schema is in place
relheight_schema = '''CREATE TABLE relative_height (
                     topoid INT, 
                     relativeheight INT)''' 
conn.execute(relheight_schema)
print(db.table_names())
query = "SELECT COUNT(*) FROM statisticalareas"
retval,retdf = pgquery(conn, query)
retdf
# Out:
# ['spatial_ref_sys', 'MeasuremntW4K', 'measurementw4k', 'world', 'organisations', 'spotheight', 'sa2_2016_aust', 'rfsnswbfpl', 'neighbourhoods', 'businessstats', 'statisticalareas', 'relative_height']
# (1, 1)
#    count
# 0    434
#    count
# 0    434

# %%
_________/\

# %%
# sa2_2016_austWkCpy _?
# rfsnswbfplWkCpy _?
#spotheight DONE 
#nighbourhoods DONE
#bussinessstats DONE
#statisticalareas DONE
#relativeheights DONE

# %%
#############3 Bring in SA1 data 
sa1_2016_aust = gpd.read_file( os.path.join(data_path,"SA1_2016_AUST.shp") )
qq  = gpd.tools.crs.epsg_from_crs(sa1_2016_aust.crs)
print(qq)
# Out:
# 4283
# /opt/jupyterhub/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: epsg_from_crs is deprecated. You can get the epsg code from GeoDataFrame (gdf) using gdf.crs.to_epsg()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sa1_2016_austnona = sa1_2016_aust.dropna()

# %%
sa1_2016_austnona
# Out:
#         SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16      SA2_NAME16  \
# 0      10102100701    1100701  101021007      11007       Braidwood
# 1      10102100702    1100702  101021007      11007       Braidwood
# 2      10102100703    1100703  101021007      11007       Braidwood
# 3      10102100704    1100704  101021007      11007       Braidwood
# 4      10102100705    1100705  101021007      11007       Braidwood
# ...            ...        ...        ...        ...             ...
# 57516  90104100404    9100404  901041004      91004  Norfolk Island
# 57517  90104100405    9100405  901041004      91004  Norfolk Island
# 57518  90104100406    9100406  901041004      91004  Norfolk Island
# 57519  90104100407    9100407  901041004      91004  Norfolk Island
# 57520  90104100408    9100408  901041004      91004  Norfolk Island
#
#       SA3_CODE16      SA3_NAME16 SA4_CODE16         SA4_NAME16 GCC_CODE16  \
# 0          10102      Queanbeyan        101     Capital Region      1RNSW
# ...

# %%
adelcolumns = ["SA2_MAIN16","SA2_5DIG16","SA3_CODE16","SA3_NAME16","SA4_CODE16","SA4_NAME16","STE_CODE16","STE_NAME16","AREASQKM16"]
sa1_2016_austdrop = sa1_2016_austnona.drop(columns=adelcolumns)
srid = 4326
def create_wkt_element(geom,srid):
    if (geom.geom_type == 'Polygon'):
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

sa1_2016_austWkCpy = usa1_2016_austdrop.copy()
sa1_2016_austWkCpy["geom"] = sa1_2016_austdrop['geometry'].apply(lambda x: create_wkt_element(x,srid))
sa1_2016_austWkCpy = sa1_2016_austWkCpy.drop(columns="geometry")
sa1_2016_austWkCpy
# Out:
#         SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16      SA2_NAME16  \
# 0      10102100701    1100701  101021007      11007       Braidwood
# 1      10102100702    1100702  101021007      11007       Braidwood
# 2      10102100703    1100703  101021007      11007       Braidwood
# 3      10102100704    1100704  101021007      11007       Braidwood
# 4      10102100705    1100705  101021007      11007       Braidwood
# ...            ...        ...        ...        ...             ...
# 57516  90104100404    9100404  901041004      91004  Norfolk Island
# 57517  90104100405    9100405  901041004      91004  Norfolk Island
# 57518  90104100406    9100406  901041004      91004  Norfolk Island
# 57519  90104100407    9100407  901041004      91004  Norfolk Island
# 57520  90104100408    9100408  901041004      91004  Norfolk Island
#
#       GCC_CODE16         GCC_NAME16  \
# 0          1RNSW        Rest of NSW
# 1          1RNSW        Rest of NSW
# 2          1RNSW        Rest of NSW
# ...

# %%
adelcolumns = ["SA2_MAIN16","SA2_5DIG16"]
sa1_2016_aust2WkCpy = sa1_2016_austWkCpy.drop(columns=adelcolumns)

# %%
sa1_2016_aust2WkCpy
# Out:
#         SA1_MAIN16 SA1_7DIG16      SA2_NAME16 GCC_CODE16         GCC_NAME16  \
# 0      10102100701    1100701       Braidwood      1RNSW        Rest of NSW
# 1      10102100702    1100702       Braidwood      1RNSW        Rest of NSW
# 2      10102100703    1100703       Braidwood      1RNSW        Rest of NSW
# 3      10102100704    1100704       Braidwood      1RNSW        Rest of NSW
# 4      10102100705    1100705       Braidwood      1RNSW        Rest of NSW
# ...            ...        ...             ...        ...                ...
# 57516  90104100404    9100404  Norfolk Island      9OTER  Other Territories
# 57517  90104100405    9100405  Norfolk Island      9OTER  Other Territories
# 57518  90104100406    9100406  Norfolk Island      9OTER  Other Territories
# 57519  90104100407    9100407  Norfolk Island      9OTER  Other Territories
# 57520  90104100408    9100408  Norfolk Island      9OTER  Other Territories
#
#                                                     geom
# ...

# %%
conn.execute("DROP TABLE IF EXISTS sa1_2016_aust")

# 2nd: ensure that the schema is in place
sa1_2016_aust_schema = '''CREATE TABLE sa1_2016_aust (
                     SA1_MAIN16 FLOAT, 
                     SA1_7DIG16 FLOAt,
                     SA2_NAME16 VARCHAR(255),  
                     GCC_CODE16 VARCHAR(255),
                     GCC_NAME16 VARCHAR(255),
                     geom GEOMETRY(MULTIPOLYGON,4326))''' 
conn.execute(sa1_2016_aust_schema)
print(db.table_names())
# Out:
# ['neighbourhoodsarr', 'sa1_2016_aust', 'MeasuremntW4K', 'measurementw4k', 'statisticalareas', 'businessstats', 'neighbourhoods', 'relative_height', 'rfsnswbfpl', 'sa2_2016_aust', 'spotheight', 'organisations', 'spatial_ref_sys']

# %%
sa1_2016_aust2WkCpy.columns = sa1_2016_aust2WkCpy.columns.str.lower()

# %%
sa1_2016_aust2WkCpy
# Out:
#         sa1_main16 sa1_7dig16      sa2_name16 gcc_code16         gcc_name16  \
# 0      10102100701    1100701       Braidwood      1RNSW        Rest of NSW
# 1      10102100702    1100702       Braidwood      1RNSW        Rest of NSW
# 2      10102100703    1100703       Braidwood      1RNSW        Rest of NSW
# 3      10102100704    1100704       Braidwood      1RNSW        Rest of NSW
# 4      10102100705    1100705       Braidwood      1RNSW        Rest of NSW
# ...            ...        ...             ...        ...                ...
# 57516  90104100404    9100404  Norfolk Island      9OTER  Other Territories
# 57517  90104100405    9100405  Norfolk Island      9OTER  Other Territories
# 57518  90104100406    9100406  Norfolk Island      9OTER  Other Territories
# 57519  90104100407    9100407  Norfolk Island      9OTER  Other Territories
# 57520  90104100408    9100408  Norfolk Island      9OTER  Other Territories
#
#                                                     geom
# ...

# %%
table_name = "sa1_2016_aust"
sa1_2016_aust2WkCpy.to_sql(table_name, conn, if_exists='append', index=False, 
                         dtype={'geom': Geometry('MultiPolygon', 4326)})
